# %%
import pandas as pd

# %%
attacks_df = pd.read_csv('data/raw/attacks.csv', encoding='latin1')

# %%
attacks_df.shape
# Out:
# (25614, 22)

# %%
cleaned_attacks_df = attacks_df.dropna(how='all')

# %%
cleaned_attacks_df.shape
# Out:
# (6096, 22)

# %%
# Returns a list of column names that have trailing whitespaces
trailing_space_cols = [col for col in attacks_df.columns if col.endswith(' ')]
print(trailing_space_cols)
# Out:
# ['Sex ', 'Species ']

# %%
age_missing = cleaned_attacks_df['Age'].isnull().mean() * 100
time_missing = cleaned_attacks_df['Time'].isnull().mean() * 100

print(f"Age missing: {age_missing:.2f}%")
print(f"Time missing: {time_missing:.2f}%")
# Out:
# Age missing: 44.65%
# Time missing: 53.28%

# %%
print(df_clean['Fatal (Y/N)'].unique())
# Out:
# Fatal (Y/N)
# N          4391
# Y          1566
# UNKNOWN      94
# NaN          32
#  N            8
# 2017          1
# F             1
# N             1
# #VALUE!       1
# n             1
# Name: count, dtype: int64

# %%
list(attacks_df.columns)
# Out:
# ['Case Number',
#  'Date',
#  'Year',
#  'Type',
#  'Country',
#  'Area',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex ',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species ',
#  'Investigator or Source',
#  'pdf',
#  'href formula',
#  'href',
#  'Case Number.1',
#  'Case Number.2',
#  'original order']

# %%
attacks_df[['Case Number','Case Number.1', 'Case Number.2']].head()
# Out:
#     Case Number Case Number.1 Case Number.2
# 0    2017.06.11    2017.06.11    2017.06.11
# 1  2017.06.10.b  2017.06.10.b  2017.06.10.b
# 2  2017.06.10.a  2017.06.10.a  2017.06.10.a
# 3  2017.06.07.R  2017.06.07.R  2017.06.07.R
# 4    2017.06.04    2017.06.04    2017.06.04
